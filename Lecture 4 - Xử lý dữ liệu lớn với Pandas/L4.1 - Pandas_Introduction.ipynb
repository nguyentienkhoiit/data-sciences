# %% [markdown]
# # I - **INTRODUCTION TO PANDAS**
#
# ![](https://i.pinimg.com/474x/6a/18/df/6a18dff64059bb388ed1046c0f2cc350.jpg)
#
# **Python** is the most popular programming language used in Data Science. Not only the incredible speed, Python also offers a good amount of libraries that are dedicated for certain jobs in Data Science, from data analysing to running statistical tests and so on.
#
# Let's get started!

# %% [markdown]
# ## 1- Import libraries

# %% [markdown]
# **Install pandas**
#
# + Open *Anaconda Powershell Prompt*
# + Activate your environment: `conda activate <your_enviroment_name>`
# + Install Pandas into your environment: `pip install pandas`

# %%
# Install pandas library:
! pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\khoi nguyen\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\khoi nguyen\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\khoi nguyen\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\khoi nguyen\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\khoi nguyen\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\khoi nguyen\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# Import Pandas
import pandas as pd

# %% [markdown]
# ## 2- Read and Overview

# %% [markdown]
# #### 2.1- Load .csv

# %%
# Load CSV file
# Tips: If your data is on Dropbox, change the link's ending part from dl=0 to dl=1
# pd.read_sql, pd.read_excel

# Read csv file from a link:
df = pd.read_csv('https://www.dropbox.com/s/vnkhtwm4m67khqb/demographic_data.csv?dl=1')

# %%
# Check type:
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# show first 5 rows:
df.head(10)
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244         78.9000
# 1           Afghanistan          AFG      35.253          5.9000
# 2                Angola          AGO      45.985         19.1000
# 3               Albania          ALB      12.877         57.2000
# 4  United Arab Emirates          ARE      11.044         88.0000
# 5             Argentina          ARG      17.716         59.9000
# 6               Armenia          ARM      13.308         41.9000
# 7   Antigua and Barbuda          ATG      16.447         63.4000
# 8             Australia          AUS      13.200         83.0000
# 9               Austria          AUT       9.400         80.6188
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %% [markdown]
# 👉 Read from **Relative Path**

# %%
# data\demographic_data.csv

# C:\Users\Lenovo\OneDrive\Desktop\my_courses\10 days of python\Lecture 4 - Pandas\data\demographic_data.csv

# %%
df2 = pd.read_csv('data\\demographic_data.csv')

# %%
df2.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %% [markdown]
# 👉 Read from **Full Path**

# %%
df3 = pd.read_csv('C:\\Users\\Lenovo\\OneDrive\\Desktop\\my_courses\\10 days of python\\Lecture 4 - Pandas\\data\\demographic_data.csv')
df3.head()

# %% [markdown]
# #### 2.2- Overview

# %%
# Show the first 5 rows
df.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# Show the first n rows:
df.head(15)
# Out:
#             Country Name Country Code  Birth rate  Internet users  \
# 0                  Aruba          ABW      10.244         78.9000
# 1            Afghanistan          AFG      35.253          5.9000
# 2                 Angola          AGO      45.985         19.1000
# 3                Albania          ALB      12.877         57.2000
# 4   United Arab Emirates          ARE      11.044         88.0000
# 5              Argentina          ARG      17.716         59.9000
# 6                Armenia          ARM      13.308         41.9000
# 7    Antigua and Barbuda          ATG      16.447         63.4000
# 8              Australia          AUS      13.200         83.0000
# 9                Austria          AUT       9.400         80.6188
# 10            Azerbaijan          AZE      18.300         58.7000
# 11               Burundi          BDI      44.151          1.3000
# 12               Belgium          BEL      11.200         82.1702
# 13                 Benin          BEN      36.440          4.9000
# 14          Burkina Faso          BFA      40.551          9.1000
#
#            Income Group
# 0           High income
# 1            Low income
# 2   Upper middle income
# 3   Upper middle income
# 4           High income
# 5           High income
# 6   Lower middle income
# 7           High income
# 8           High income
# 9           High income
# 10  Upper middle income
# 11           Low income
# 12          High income
# 13           Low income
# 14           Low income

# %%
# Show the last 5 rows (or last n rows)
df.tail()
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
# show the last 10 rows:
df.tail(10)
# Out:
#               Country Name Country Code  Birth rate  Internet users  \
# 185  Virgin Islands (U.S.)          VIR      10.700            45.3
# 186                Vietnam          VNM      15.537            43.9
# 187                Vanuatu          VUT      26.739            11.3
# 188     West Bank and Gaza          PSE      30.394            46.6
# 189                  Samoa          WSM      26.172            15.3
# 190            Yemen, Rep.          YEM      32.947            20.0
# 191           South Africa          ZAF      20.850            46.5
# 192       Congo, Dem. Rep.          COD      42.394             2.2
# 193                 Zambia          ZMB      40.471            15.4
# 194               Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 185          High income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
# Show 5 random rows
df.sample(10)
# Out:
#      Country Name Country Code  Birth rate  Internet users  \
# 127         Niger          NER      49.661            1.70
# 171  Turkmenistan          TKM      21.322            9.60
# 45        Germany          DEU       8.500           84.17
# 69        Grenada          GRD      19.334           35.00
# 160      Suriname          SUR      18.455           37.40
# 173         Tonga          TON      25.409           35.00
# 13          Benin          BEN      36.440            4.90
# 178        Uganda          UGA      43.474           16.20
# 25       Barbados          BRB      12.188           73.00
# 138   Philippines          PHL      23.790           37.00
#
#             Income Group
# 127           Low income
# 171  Upper middle income
# 45           High income
# 69   Upper middle income
# 160  Upper middle income
# 173  Upper middle income
# 13            Low income
# 178           Low income
# 25           High income
# 138  Lower middle income

# %% [markdown]
# 👉 Dataframe's shape:

# %%
# Show shape of the dataframe
df.shape
# Out:
# (195, 5)

# %% [markdown]
# 👉 Dataframe's infos: datatype, null count

# %%
# Show info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
# In case df.info() not show non-null count:
df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %% [markdown]
# 👉 Describe dataframe: descriptive statistics.

# %%
# Overview descriptive statistics of numeric columns:
df.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
# Overview descriptive statistics of all columns:
df.describe(include='all')
# Out:
#        Country Name Country Code  Birth rate  Internet users Income Group
# count           195          195  195.000000      195.000000          195
# unique          195          195         NaN             NaN            4
# top           Aruba          ABW         NaN             NaN  High income
# freq              1            1         NaN             NaN           67
# mean            NaN          NaN   21.469928       42.076471          NaN
# std             NaN          NaN   10.605467       29.030788          NaN
# min             NaN          NaN    7.900000        0.900000          NaN
# 25%             NaN          NaN   12.120500       14.520000          NaN
# 50%             NaN          NaN   19.680000       41.000000          NaN
# 75%             NaN          NaN   29.759500       66.225000          NaN
# max             NaN          NaN   49.661000       96.546800          NaN

# %% [markdown]
# > **Mean, median, mode, range:**
#
# <img src="https://images.squarespace-cdn.com/content/v1/54905286e4b050812345644c/1626904601177-6NNQ5U9GIX0XKG64AB0B/Snip20210721_15.png" width="600">

# %% [markdown]
# > **Standard Deviation (STD)**
# + When two data sets have the same mean, the one with higher STD is more variability than the one lower STD.
# + In the case of two data sets with unequal mean values, it is not meaningful to compare their STD.
#
# <img src="https://unitrain.edu.vn/wp-content/uploads/2022/02/Capture-3.png" width="600">

# %% [markdown]
# 👉 Show all columns:

# %%
# get list of all columns
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %% [markdown]
# #### 2.3- Select single or multiple columns:

# %%
# Select a column
df['Income Group']
# Out:
# 0              High income
# 1               Low income
# 2      Upper middle income
# 3      Upper middle income
# 4              High income
#               ...
# 190    Lower middle income
# 191    Upper middle income
# 192             Low income
# 193    Lower middle income
# 194             Low income
# Name: Income Group, Length: 195, dtype: object

# %%
# Select multiple columns:
df[['Birth rate', 'Country Code']]
# Out:
#      Birth rate Country Code
# 0        10.244          ABW
# 1        35.253          AFG
# 2        45.985          AGO
# 3        12.877          ALB
# 4        11.044          ARE
# ..          ...          ...
# 190      32.947          YEM
# 191      20.850          ZAF
# 192      42.394          COD
# 193      40.471          ZMB
# 194      35.715          ZWE
#
# [195 rows x 2 columns]

# %%
# Overview of categorical columns
df['Income Group'].describe()
# Out:
# count             195
# unique              4
# top       High income
# freq               67
# Name: Income Group, dtype: object

# %% [markdown]
# 👉 Get unique values:

# %%
# Get all values in a series (=field = column)
df['Income Group'].unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %% [markdown]
# 👉 Get number of unique values:

# %%
df['Income Group'].nunique()
# Out:
# 4

# %% [markdown]
# 👉 Get value counts:

# %%
# See distribute of a series
df['Income Group'].value_counts()
# Out:
# Income Group
# High income            67
# Lower middle income    50
# Upper middle income    48
# Low income             30
# Name: count, dtype: int64

# %% [markdown]
# ## 3- Filter

# %% [markdown]
# ***Comparison in Pandas:***
#
# ```python
#         equal: ==
#
#         different: !=
#
#         more than: >
#
#         less than: <
#
#         more than or equal: >=
#
#         less than or equal: <=
#
#         and: &
#
#         or: |
#
# ```

# %%
df.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# Get all rows with Birth rate > 20:
df[df['Birth rate'] > 20].shape[0]
# Out:
# 95

# %%
# Choose all data with Internet rate less than 20
# YOUR CODE HERE:
df[df['Internet users'] <= 20]
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 1         Afghanistan          AFG      35.253             5.9
# 2              Angola          AGO      45.985            19.1
# 11            Burundi          BDI      44.151             1.3
# 13              Benin          BEN      36.440             4.9
# 14       Burkina Faso          BFA      40.551             9.1
# ..                ...          ...         ...             ...
# 189             Samoa          WSM      26.172            15.3
# 190       Yemen, Rep.          YEM      32.947            20.0
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 1             Low income
# 2    Upper middle income
# 11            Low income
# 13            Low income
# 14            Low income
# ..                   ...
# 189  Lower middle income
# 190  Lower middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [66 rows x 5 columns]

# %%
# Birth rate > 20 AND Internet users < 3
df[(df['Birth rate'] > 20) & (df['Internet users'] < 3)]
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 11            Burundi          BDI      44.151             1.3
# 52            Eritrea          ERI      34.800             0.9
# 55           Ethiopia          ETH      32.925             1.9
# 64             Guinea          GIN      37.337             1.6
# 127             Niger          NER      49.661             1.7
# 154      Sierra Leone          SLE      36.729             1.7
# 156           Somalia          SOM      43.891             1.5
# 167              Chad          TCD      45.745             2.3
# 172       Timor-Leste          TLS      35.755             1.1
# 192  Congo, Dem. Rep.          COD      42.394             2.2
#
#             Income Group
# 11            Low income
# 52            Low income
# 55            Low income
# 64            Low income
# 127           Low income
# 154           Low income
# 156           Low income
# 167           Low income
# 172  Lower middle income
# 192           Low income

# %%
# Birth rate > 40 OR Internet users < 3
df[(df['Birth rate'] > 40) | (df['Internet users'] < 3)]
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 2              Angola          AGO      45.985            19.1
# 11            Burundi          BDI      44.151             1.3
# 14       Burkina Faso          BFA      40.551             9.1
# 52            Eritrea          ERI      34.800             0.9
# 55           Ethiopia          ETH      32.925             1.9
# 64             Guinea          GIN      37.337             1.6
# 65        Gambia, The          GMB      42.525            14.0
# 115              Mali          MLI      44.138             3.5
# 117           Myanmar          MMR      18.119             1.6
# 127             Niger          NER      49.661             1.7
# 128           Nigeria          NGA      40.045            38.0
# 154      Sierra Leone          SLE      36.729             1.7
# 156           Somalia          SOM      43.891             1.5
# 167              Chad          TCD      45.745             2.3
# 172       Timor-Leste          TLS      35.755             1.1
# 178            Uganda          UGA      43.474            16.2
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
#
#             Income Group
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 52            Low income
# 55            Low income
# 64            Low income
# 65            Low income
# 115           Low income
# 117  Lower middle income
# 127           Low income
# 128  Lower middle income
# 154           Low income
# 156           Low income
# 167           Low income
# 172  Lower middle income
# 178           Low income
# 192           Low income
# 193  Lower middle income

# %%
# Show me which contries have: (15 < Birth rate < 16) OR (43 < Internet users < 44):
# Your code here:
df[((df['Birth rate'] > 15) & (df['Birth rate'] < 16)) | ((df['Internet users'] > 43) & (df['Internet users'] < 44))]

# %%
df[(df['Income Group'] == 'High income')]
# Out:
#               Country Name Country Code  Birth rate  Internet users  \
# 0                    Aruba          ABW      10.244           78.90
# 4     United Arab Emirates          ARE      11.044           88.00
# 5                Argentina          ARG      17.716           59.90
# 7      Antigua and Barbuda          ATG      16.447           63.40
# 8                Australia          AUS      13.200           83.00
# ..                     ...          ...         ...             ...
# 174    Trinidad and Tobago          TTO      14.590           63.80
# 180                Uruguay          URY      14.374           57.69
# 181          United States          USA      12.500           84.20
# 184          Venezuela, RB          VEN      19.842           54.90
# 185  Virgin Islands (U.S.)          VIR      10.700           45.30
#
#     Income Group
# 0    High income
# 4    High income
# 5    High income
# 7    High income
# 8    High income
# ..           ...
# 174  High income
# 180  High income
# 181  High income
# 184  High income
# 185  High income
#
# [67 rows x 5 columns]

# %%
df[df['Income Group'] == 'High income']['Country Name']
# Out:
# 0                      Aruba
# 4       United Arab Emirates
# 5                  Argentina
# 7        Antigua and Barbuda
# 8                  Australia
#                ...
# 174      Trinidad and Tobago
# 180                  Uruguay
# 181            United States
# 184            Venezuela, RB
# 185    Virgin Islands (U.S.)
# Name: Country Name, Length: 67, dtype: object

# %% [markdown]
# ## 4- Location `.loc[] / .iloc[]`
#
# <img src="https://dataindependent.com/wp-content/uploads/2021/12/Screen-Shot-2020-09-20-at-9.35.33-AM-1024x666-1.png" width="600">

# %% [markdown]
# ### 4.1- loc - Direct Location on DataFrame

# %%
df.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# Get all field country Code:
df.loc[:, 'Country Code']
# Out:
# 0      ABW
# 1      AFG
# 2      AGO
# 3      ALB
# 4      ARE
#       ...
# 190    YEM
# 191    ZAF
# 192    COD
# 193    ZMB
# 194    ZWE
# Name: Country Code, Length: 195, dtype: object

# %%
df.loc[:, ['Country Code', 'Internet users']]
# Out:
#     Country Code  Internet users
# 0            ABW            78.9
# 1            AFG             5.9
# 2            AGO            19.1
# 3            ALB            57.2
# 4            ARE            88.0
# ..           ...             ...
# 190          YEM            20.0
# 191          ZAF            46.5
# 192          COD             2.2
# 193          ZMB            15.4
# 194          ZWE            18.5
#
# [195 rows x 2 columns]

# %%
# Get Vietnam's country code:
df.loc[df['Country Name'] == 'Vietnam', 'Country Code']
# Out:
# 186    VNM
# Name: Country Code, dtype: object

# %%
# Get Aruba, Albania, Vietnam internet users and Income Group:
# df.loc[df['Country Name'].isin(['Aruba', 'Albania', 'Vietnam']), ['Internet users', 'Income Group']]
df.loc[df['Country Name'].isin(['Aruba', 'Albania', 'Vietnam']), ['Internet users', 'Income Group']]

# %%
df.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# Get all countries from Aruba to United Arab Emirates:
# df.loc[[0, 1, 2, 3, 4], ['Country Name','Income Group', 'Internet users']]
df.loc[ [0, 1, 2, 3, 4] , :]
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.loc[:4, :]
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %% [markdown]
# 👉 Change value:

# %%
df.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# Change Income Group of Vietnam to High Income:
df.loc[df['Country Name'] == 'Vietnam', 'Income Group'] = 'High Income'

# %%
df.loc[df['Country Name'] == 'Vietnam']
# Out:
#     Country Name Country Code  Birth rate  Internet users Income Group
# 186      Vietnam          VNM      15.537            43.9  High Income

# %%
# Change Internet user of Aruba and Afghanistan, Albania:
df.loc[df['Country Name'].isin(['Aruba', 'Afghanistan', 'Albania']), 'Internet users'] = [90, 10, 80]

# %% [markdown]
# ### 4.2. iloc - Integer Location on DataFrame

# %%
df.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            90.0
# 1           Afghanistan          AFG      35.253            10.0
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            80.0
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# get all values of country code:
df.loc[:, 'Country Code']
# Out:
# 0      ABW
# 1      AFG
# 2      AGO
# 3      ALB
# 4      ARE
#       ...
# 190    YEM
# 191    ZAF
# 192    COD
# 193    ZMB
# 194    ZWE
# Name: Country Code, Length: 195, dtype: object

# %%
# Select the whole row --- integer loc
df.iloc[3]
# Out:
# Country Name                  Albania
# Country Code                      ALB
# Birth rate                     12.877
# Internet users                   80.0
# Income Group      Upper middle income
# Name: 3, dtype: object

# %%
df.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            90.0
# 1           Afghanistan          AFG      35.253            10.0
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            80.0
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# Select a certain data point: get birth rate of Albania:
df.iloc[3, 2]
# Out:
# np.float64(12.877)

# %%
# Choose all countries to United Arab Emirates:
df.iloc[:5]
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            90.0
# 1           Afghanistan          AFG      35.253            10.0
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            80.0
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# Vietnam has index is 186, Can you help me to get Birth rate, Internet users and Income Group of Vietnam by using .iloc[]
# Your code here:
df.iloc[186, 2:]
# Out:
# Birth rate             15.537
# Internet users           43.9
# Income Group      High Income
# Name: 186, dtype: object

# %% [markdown]
# 👉 Change value:

# %%
# Change Internet users of Angola to 100:
df.iloc[2, 3] = 100

# %%
# Change Internet users of Aruba, Afghanistan, Albania to [20, 40, 60]:
df.iloc[ [0, 1, 3] , 3] = [20, 40, 60]
# Out:
# 0    90.0
# 1    10.0
# 3    80.0
# Name: Internet users, dtype: float64

# %%
df.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.set_index('Country Name', inplace = True)

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.loc['Afghanistan', 'Birth rate']
# Out:
# np.float64(35.253)

# %%
df.iloc[1, 1]
# Out:
# np.float64(35.253)

# %% [markdown]
# ## 5- Aggregation Functions

# %% [markdown]
# **The Popular Aggregation Functions in Pandas**
#
# `mean()`: Compute mean of groups
#
# `sum()`: Compute sum of group values
#
# `count()`: Compute count of group
#
# `std()`: Standard deviation of groups
#
# `var()`: Compute variance of groups
#
# `describe()`: Generates descriptive statistics
#
# `first()`: Compute first of group values
#
# `last()`: Compute last of group values
#
# `nth()`: Take nth value, or a subset if n is a list
#
# `min()`: Compute min of group values
#
# `max()`: Compute max of group values

# %%
# Reload dataframe
df = pd.read_csv('data\\demographic_data.csv')

# %%
df.head(5)
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# Get average of internet users
df['Internet users'].mean()
# Out:
# np.float64(42.07647089194872)

# %%
# Get min of birth rate:
df['Birth rate'].min()
# Out:
# np.float64(7.9)

# %%
# Get max of Birth rate:
# Your code here
df['Birth rate'].max()
# Out:
# np.float64(49.661)

# %%
# Which country has largest Internet users
max_inter_users = df['Internet users'].max()
max_inter_users
# Out:
# np.float64(96.5468)

# %%
df[df['Internet users'] == max_inter_users]
# Out:
#    Country Name Country Code  Birth rate  Internet users Income Group
# 84      Iceland          ISL        13.4         96.5468  High income

# %%
# Calculate mean of Internet users of Low income countries:
df[df['Income Group'] == 'Low income']['Internet users'].mean()
# Out:
# np.float64(5.988333333333333)

# %%
# Comparing birth rate mean of Low income contries and High income countries:
# 1: Calculate birth rate mean of Low income countries:
# your code here:
df[df['Income Group'] == 'Low income']['Birth rate'].mean()
# Out:
# np.float64(37.23826666666666)

# %%
# 1: Calculate birth rate mean of high income countries:
# your code here:
df[df['Income Group'] == 'High income']['Birth rate'].mean()
# Out:
# np.float64(12.753432835820895)

# %% [markdown]
# ## 6- Sort value:

# %%
df.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# Sort value by internet users following from small to big (A->Z)
df = df.sort_values('Internet users')
df
# Out:
#     Country Name Country Code  Birth rate  Internet users         Income Group
# 52       Eritrea          ERI      34.800          0.9000           Low income
# 172  Timor-Leste          TLS      35.755          1.1000  Lower middle income
# 11       Burundi          BDI      44.151          1.3000           Low income
# 156      Somalia          SOM      43.891          1.5000           Low income
# 117      Myanmar          MMR      18.119          1.6000  Lower middle income
# ..           ...          ...         ...             ...                  ...
# 47       Denmark          DNK      10.000         94.6297          High income
# 163       Sweden          SWE      11.800         94.7836          High income
# 131       Norway          NOR      11.600         95.0534          High income
# 22       Bermuda          BMU      10.400         95.3000          High income
# 84       Iceland          ISL      13.400         96.5468          High income
#
# [195 rows x 5 columns]

# %%
# Sorting by internet users from big to small (Z->A)
df.sort_values('Internet users', ascending = False, inplace = True)
df
# Out:
#     Country Name Country Code  Birth rate  Internet users         Income Group
# 84       Iceland          ISL      13.400         96.5468          High income
# 22       Bermuda          BMU      10.400         95.3000          High income
# 131       Norway          NOR      11.600         95.0534          High income
# 163       Sweden          SWE      11.800         94.7836          High income
# 47       Denmark          DNK      10.000         94.6297          High income
# ..           ...          ...         ...             ...                  ...
# 64        Guinea          GIN      37.337          1.6000           Low income
# 156      Somalia          SOM      43.891          1.5000           Low income
# 11       Burundi          BDI      44.151          1.3000           Low income
# 172  Timor-Leste          TLS      35.755          1.1000  Lower middle income
# 52       Eritrea          ERI      34.800          0.9000           Low income
#
# [195 rows x 5 columns]

# %%
df.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 1           Afghanistan          AFG      35.253             5.9
# 3               Albania          ALB      12.877            57.2
# 49              Algeria          DZA      24.738            16.5
# 2                Angola          AGO      45.985            19.1
# 7   Antigua and Barbuda          ATG      16.447            63.4
#
#            Income Group
# 1            Low income
# 3   Upper middle income
# 49  Upper middle income
# 2   Upper middle income
# 7           High income

# %%
# Sort Country name from A->Z:
df.sort_values('Country Name', inplace = True)
df
# Out:
#               Country Name Country Code  Birth rate  Internet users  \
# 1              Afghanistan          AFG      35.253             5.9
# 3                  Albania          ALB      12.877            57.2
# 49                 Algeria          DZA      24.738            16.5
# 2                   Angola          AGO      45.985            19.1
# 7      Antigua and Barbuda          ATG      16.447            63.4
# ..                     ...          ...         ...             ...
# 185  Virgin Islands (U.S.)          VIR      10.700            45.3
# 188     West Bank and Gaza          PSE      30.394            46.6
# 190            Yemen, Rep.          YEM      32.947            20.0
# 193                 Zambia          ZMB      40.471            15.4
# 194               Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 1             Low income
# 3    Upper middle income
# 49   Upper middle income
# 2    Upper middle income
# 7            High income
# ..                   ...
# 185          High income
# 188  Lower middle income
# 190  Lower middle income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]

# %%
# Find top 10 country by Largest birth rate:
df.sort_values('Birth rate', ascending = False).head(10)
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 127             Niger          NER      49.661             1.7
# 2              Angola          AGO      45.985            19.1
# 167              Chad          TCD      45.745             2.3
# 11            Burundi          BDI      44.151             1.3
# 115              Mali          MLI      44.138             3.5
# 156           Somalia          SOM      43.891             1.5
# 178            Uganda          UGA      43.474            16.2
# 65        Gambia, The          GMB      42.525            14.0
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 14       Burkina Faso          BFA      40.551             9.1
#
#             Income Group
# 127           Low income
# 2    Upper middle income
# 167           Low income
# 11            Low income
# 115           Low income
# 156           Low income
# 178           Low income
# 65            Low income
# 192           Low income
# 14            Low income

# %% [markdown]
# ## 7- Concatinating multiple dataframes:
#
# <img src="https://datascienceparichay.com/wp-content/uploads/2020/09/pandas-concat-dataframes.png" width="600">
#
# With concatenation, your datasets are just stitched together along an axis — either the row axis or column axis.

# %%
df = pd.read_csv('data/demographic_data.csv')
df.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# Load demographic_data_2 table:
df2 = pd.read_excel('data\\demographic_data_2.xlsx')
df2.head()
# Out:
#     Country Name Country Code  Birth rate  Internet users         Income Group
# 0     Air Nomads          ANM        12.3         96.5468          High income
# 1    Water Tribe          WTB        13.2         95.3000           Low income
# 2  Earth Kingdom          EKD        15.4         95.0534  Upper middle income
# 3    Fire Nation          FNT        16.7         94.7836  Lower middle income

# %%
# If you face the bug "'Missing optional dependency 'openpyxl'" then run this code to install openyxl library
# after that, run the above one again.
! pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.5

# %%
# Concat 2 tables:
pd.concat([df, df2], axis = 0)
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244         78.9000
# 1             Afghanistan          AFG      35.253          5.9000
# 2                  Angola          AGO      45.985         19.1000
# 3                 Albania          ALB      12.877         57.2000
# 4    United Arab Emirates          ARE      11.044         88.0000
# ..                    ...          ...         ...             ...
# 194              Zimbabwe          ZWE      35.715         18.5000
# 0              Air Nomads          ANM      12.300         96.5468
# 1             Water Tribe          WTB      13.200         95.3000
# 2           Earth Kingdom          EKD      15.400         95.0534
# 3             Fire Nation          FNT      16.700         94.7836
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# 194           Low income
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Lower middle income
#
# [199 rows x 5 columns]

# %%
# Concat 2 tables with ignore_index:
df3 = pd.concat([df, df2], axis = 0, ignore_index = True)
df3
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244         78.9000
# 1             Afghanistan          AFG      35.253          5.9000
# 2                  Angola          AGO      45.985         19.1000
# 3                 Albania          ALB      12.877         57.2000
# 4    United Arab Emirates          ARE      11.044         88.0000
# ..                    ...          ...         ...             ...
# 194              Zimbabwe          ZWE      35.715         18.5000
# 195            Air Nomads          ANM      12.300         96.5468
# 196           Water Tribe          WTB      13.200         95.3000
# 197         Earth Kingdom          EKD      15.400         95.0534
# 198           Fire Nation          FNT      16.700         94.7836
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# 194           Low income
# 195          High income
# 196           Low income
# 197  Upper middle income
# 198  Lower middle income
#
# [199 rows x 5 columns]

# %% [markdown]
# ## 8- Merge (Join) 2 dataframes:
#
# <img src="https://data36.com/wp-content/uploads/2018/08/4-pandas-merge-inner-outer-left-right-1024x771.png" width="600">
#
# > When you want to combine data objects based on one or more keys, similar to what you’d do in a relational database, merge() is the tool you need. More specifically, merge() is most useful when you want to combine rows that share data.

# %%
df.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# Load income group table:
income_gr = pd.read_excel('data\\income_group.xlsx')
income_gr.head()
# Out:
#           Income Group Income (updated)  Income (2020)
# 0          High income         > 12,695       > 12,535
# 1           Low income          < 1,046        < 1,035
# 2  Upper middle income    4,096 -12,695  4,046 -12,535
# 3  Lower middle income    1,046 – 4,095  1,035 – 4,045
# 4    Super High income         > 20,000       > 25,000

# %%
# Now you want to know detail of each Income group, but this information was stored in income_group table.
# So, to get them, you need to use merge function:
df = pd.merge(
    left = df,
    right = income_gr[['Income Group', 'Income (updated)']],
    how = 'left',
    on = 'Income Group'
)

# %%
df.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group Income (updated)_x Income (updated)_y
# 0          High income           > 12,695           > 12,695
# 1           Low income            < 1,046            < 1,046
# 2  Upper middle income      4,096 -12,695      4,096 -12,695
# 3  Upper middle income      4,096 -12,695      4,096 -12,695
# 4          High income           > 12,695           > 12,695

# %%
# Incase how = 'right':
df4 = pd.merge(
    left = df,
    right = income_gr[['Income Group', 'Income (updated)']],
    how = 'right',
    on = 'Income Group'
)
df4.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users Income Group  \
# 0                 Aruba          ABW      10.244            78.9  High income
# 1  United Arab Emirates          ARE      11.044            88.0  High income
# 2             Argentina          ARG      17.716            59.9  High income
# 3   Antigua and Barbuda          ATG      16.447            63.4  High income
# 4             Australia          AUS      13.200            83.0  High income
#
#   Income (updated)_x Income (updated)_y Income (updated)
# 0           > 12,695           > 12,695         > 12,695
# 1           > 12,695           > 12,695         > 12,695
# 2           > 12,695           > 12,695         > 12,695
# 3           > 12,695           > 12,695         > 12,695
# 4           > 12,695           > 12,695         > 12,695

# %%
df5 = pd.merge(
    left = df,
    right = income_gr[['Income Group', 'Income (updated)']],
    how = 'inner',
    on = 'Income Group'
)

df5.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group Income (updated)_x Income (updated)_y Income (updated)
# 0          High income           > 12,695           > 12,695         > 12,695
# 1           Low income            < 1,046            < 1,046          < 1,046
# 2  Upper middle income      4,096 -12,695      4,096 -12,695    4,096 -12,695
# 3  Upper middle income      4,096 -12,695      4,096 -12,695    4,096 -12,695
# 4          High income           > 12,695           > 12,695         > 12,695

# %%
df6 = pd.merge(
    left = df,
    right = income_gr[['Income Group', 'Income (updated)']],
    how = 'outer',
    on = 'Income Group'
)

df6.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users Income Group  \
# 0                 Aruba          ABW      10.244            78.9  High income
# 1  United Arab Emirates          ARE      11.044            88.0  High income
# 2             Argentina          ARG      17.716            59.9  High income
# 3   Antigua and Barbuda          ATG      16.447            63.4  High income
# 4             Australia          AUS      13.200            83.0  High income
#
#   Income (updated)_x Income (updated)_y Income (updated)
# 0           > 12,695           > 12,695         > 12,695
# 1           > 12,695           > 12,695         > 12,695
# 2           > 12,695           > 12,695         > 12,695
# 3           > 12,695           > 12,695         > 12,695
# 4           > 12,695           > 12,695         > 12,695

# %% [markdown]
# ## 9- Field Operators

# %%
df.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group Income (updated)_x Income (updated)_y
# 0          High income           > 12,695           > 12,695
# 1           Low income            < 1,046            < 1,046
# 2  Upper middle income      4,096 -12,695      4,096 -12,695
# 3  Upper middle income      4,096 -12,695      4,096 -12,695
# 4          High income           > 12,695           > 12,695

# %%
# Example: Add 5 to Birth rate:
df['New birth rate'] = df['Birth rate'] + 5
df
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group Income (updated)_x Income (updated)_y  New birth rate
# 0            High income           > 12,695           > 12,695          15.244
# 1             Low income            < 1,046            < 1,046          40.253
# 2    Upper middle income      4,096 -12,695      4,096 -12,695          50.985
# 3    Upper middle income      4,096 -12,695      4,096 -12,695          17.877
# 4            High income           > 12,695           > 12,695          16.044
# ..                   ...                ...                ...             ...
# 190  Lower middle income      1,046 – 4,095      1,046 – 4,095          37.947
# 191  Upper middle income      4,096 -12,695      4,096 -12,695          25.850
# 192           Low income            < 1,046            < 1,046          47.394
# 193  Lower middle income      1,046 – 4,095      1,046 – 4,095          45.471
# 194           Low income            < 1,046            < 1,046          40.715
#
# [195 rows x 8 columns]

# %%
# Example: 50% of birth rate:
df['new birth rate 2'] = df['Birth rate'] * 0.5
df

# %%
# Ex4: Birth rate * Internet users
df['temp'] =  df['Birth rate'] * df['Internet users']
df

# %% [markdown]
# ## 10- Save file:

# %%
# Save dataframe as csv file:
df.to_csv('export_data\\country_demography_tam.csv', index = False)

# %%
df5 = pd.read_csv('export_data\\country_demography_tam.csv')
df5

# %%
# Save dataframe as excel file:
df.to_excel('export_data\\country_demography_tam_Excel.xlsx', index = False)

# %%
pd.read_excel('export_data\\country_demography_tam_Excel.xlsx')

# %% [markdown]
# # II - **LEVEL-UP PANDAS**
#
# Hello and welcome back to Pandas. In the previous session, we have learnt how to load and overview the dataset with Pandas, also some basic syntax to select, filter and sort.
#
# In today session, we will continue to explore further in
# - Groupby
# - Apply
# - Pivot_table
# - Time series

# %%
df = pd.read_csv('data\\restaurant.csv')
df.head()

# %% [markdown]
# ## 1- Groupby

# %% [markdown]
# By `groupby` we are referring to a process involving one or more of the following steps:
# * **Splitting** the data into groups based on some criteria
# * **Applying** a function to each group independently
# * **Combining** the results into a data structure
#
# <img src="https://www.w3resource.com/w3r_images/pandas-groupby-split-apply-combine.svg" width="600">
#
# **Common Aggregation Functions in Pandas**
#
# `mean()`: Compute mean of groups
#
# `sum()`: Compute sum of group values
#
# `size()`: Compute group sizes
#
# `count()`: Compute count of group
#
# `std()`: Standard deviation of groups
#
# `var()`: Compute variance of groups
#
# `describe()`: Generates descriptive statistics
#
# `first()`: Compute first of group values
#
# `last()`: Compute last of group values
#
# `nth()`: Take nth value, or a subset if n is a list
#
# `min()`: Compute min of group values
#
# `max()`: Compute max of group values```

# %%
df.head()

# %%
# Trung bình tip theo ngày:
df.groupby('day')['tip'].mean()

# %%
# Chuyển thành dạng dataframe
df.groupby('day')['tip'].mean().reset_index()

# %%
# 🤔 Ngày nào có tổng Total_bill là nhiều nhất:
# Your code here
df.groupby('day')['total_bill'].sum().reset_index()

# %% [markdown]
# ***Group by multiple values, one method***

# %%
df.head()

# %%
# GROUP BY TWO COLUMNS: Groupby the dataset by day and sex
# Between Male and Female who has mean of tip more?
df.groupby(['day', 'sex'])['tip'].mean().reset_index()

# %% [markdown]
# ***Groupby one value, multiple methods***

# %%
# Groupby on one value, multiple methods. --> Hàm .agg
df.groupby('day')['tip', 'total_bill'].mean()

# %%
# Vừa tính trung bình và vừa tính tổng tiền tip và total bill theo ngày:
df.groupby('day')['tip', 'total_bill'].agg(['mean', 'sum'])

# %% [markdown]
# ***Groupby multiple values, multiple methods***

# %%
# Groupby on multiple values, multiple methods.
# Dùng dictionary để assign từng method cho từng value 
# df.groupby('day').agg({'tip': 'sum', 'total_bill': 'mean'}).reset_index()
df.groupby('time')['tip', 'total_bill'].agg(
    {
        'tip': 'mean', 
        'total_bill': 'sum'
    }
).reset_index()

# %% [markdown]
# ## 2- Pivot Table

# %% [markdown]
# A pivot table is a table of statistics that summarizes the data of a more extensive table. This summary might include sums, averages, or other statistics, which the pivot table groups together in a meaningful way.
#
#
# OFFICIAL DOCUMENTATION ▸ https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html
#
# EXPLANATION ▸ https://pbpython.com/pandas-pivot-table-explained.html
#
# <img src="https://pandas.pydata.org/docs/_images/reshaping_pivot.png" width="600">

# %%
# Trung bình total bill của nam và nữ trong các ngày trong tuần - groupby:
df.groupby(['day', 'sex'])['total_bill'].mean()

# %%
# Trung bình total bill của nam và nữ trong các ngày trong tuần - pivot table
pd.pivot_table(
    data = df,
    values= 'total_bill',
    index = 'day',
    columns= 'sex',
    aggfunc= 'mean'
)

# %%
# Perform pivot table on multiple value.
# Trung bình tiền tip và total_bill của nam và nữ trong các ngày trong tuần
pd.pivot_table(
    data = df,
    values= ['tip', 'total_bill'],
    index = 'day',
    columns= 'sex',
    aggfunc= 'mean'
)

# %%
# Perform pivot table on multiple value and multiple aggregation function
# Đối với tiền tip ta tính mean, còn tiền bill ta tính sum:
pd.pivot_table(
    data = df,
    values= ['tip', 'total_bill'],
    index = 'day',
    columns= 'sex',
    aggfunc= {
        'tip': 'mean',
        'total_bill': 'sum'
    }
)

# %% [markdown]
# ## 3- Apply

# %% [markdown]
# The Pandas `apply()` is used to apply a function along an axis of the DataFrame or on values of Series.

# %% [markdown]
# Classify if ```tip``` amount > 3 then High, else it is Low.

# %%
df.head()

# %%
# Function nhận parameter là từng row 
def check_tip(r):
    if r['tip'] >= 3:
        return 'high tip'
    else:
        return 'low tip'
    
# %time
df['cus_type'] = df.apply(check_tip, axis = 1)

# %%
# xét total_bill, chỉ xét cho nữ, với điều kiện nếu ttb < 20 => poor girl, ngược lại là rich girl:
def check_total_bill(r):
    if r['total_bill'] < 20:
        return 'poor girl'
    else:
        return 'rich girl'

df.loc[df.sex == 'Female', 'female_cus_type'] = df.apply(check_total_bill, axis=1)

# %%
# option 2: using loc:
# %time
df.loc[df.tip < 3, 'cus_type_2'] = 'low tip'
df.loc[df.tip >= 3, 'cus_type_2'] = 'high tip'

# %% [markdown]
# ## 4- Working with time-series:
#
# <img src='https://media.giphy.com/media/jq07NJW0WA0I5Q7qQ4/giphy.gif' width=600>
#
# **Pandas** was developed in the context of financial modeling, so as you might expect, it contains a fairly extensive set of tools for working with dates, times, and time-indexed data. Date and time data in Pandas comes in three types:

# %%
import numpy as np
from datetime import datetime

# %%
! pip install numpy

# %%
dftime = pd.read_excel('data\datetime_demo.xlsx')
dftime.head()

# %% [markdown]
# 👉 Convert to datetime format:

# %%
dftime.launched = pd.to_datetime(dftime.launched)
dftime['deadline'] = pd.to_datetime(dftime['deadline'])

# %% [markdown]
# 👉 Convert to datetime with format:
#
# https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior

# %%
# Below casting to datetime code will result to error because Python not smart enough to understand the messy date:
dftime['messy_date'] = pd.to_datetime(dftime['messy_date'])

# %%
dftime['messy_date'] = pd.to_datetime(dftime['messy_date'], format = r'&%m\\%Y%d')

# %% [markdown]
# 👉 Timestamp:
#
# **Pandas** builds upon both Python and Numpy to provide a **Timestamp** object, which combines the ease-of-use of Python `datetime` and `dateutil` with the efficient storage and vectorized interface of `numpy.datetime64`. From a group of these **Timestamp** objects, Pandas can construct a DatetimeIndex that can be used to index data in a Series or DataFrame; we'll see many examples of this below.
#
# Oftentimes, time-series data is read as string datatype. We can use Pandas tools to parse a flexibly formatted string date to timestamp.

# %%
start = pd.to_datetime('12/21/2015')
start

# %%
# get timestamp right now:
now = pd.Timestamp.now()
now

# %% [markdown]
# 👉 TimeDelta:
#
# As mentioned at the beginning, TimeDelta is the difference in duration of two moments. In Pandas, a timedelta can be created by taking the difference of two timestamps.

# %%
start = pd.to_datetime('02/02/2015')
stop = pd.to_datetime('03/02/2015')

stop-start

# %%
now + 15

# %%
now + pd.to_timedelta(15, unit='D')

# %%
# You can't directly add a number to a date
# First you have to convert the number to timedelta datatype
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_timedelta.html

# Cộng thêm 15 ngày từ bây giờ
now + pd.to_timedelta(15, 'D')

# %% [markdown]
# 👉 Extract the value at a certain timeunit (day, month, year, etc) from a SERIES of timestamp:
# ```python
#         # Extract year, month, day
#         date_series.dt.year
#         date_series.dt.month
#         date_series.dt.day
#
#         # Extract hour, minute, second
#         date_series.dt.hour
#         date_series.dt.minute
#         date_series.dt.second
#
#         # Extract dayofweek, week, quarter
#         date_series.dt.dayofweek
#         date_series.dt.isocalendar().week
#         date_series.dt.quarter
#
#         # Extract year-month
#         date_series.dt.to_period('M')
# ```

# %%
dftime.head()

# %%
# Extract only year from launched field:
dftime['launched_year']  = dftime['launched'].dt.year
dftime

# %%
# Extract only hour from launched field:
dftime['launched_hour'] = dftime['launched'].dt.hour
dftime.head()

# %%
# Extract year-month from deadline field:
# Your code here:
dftime['deadline_year_month'] = dftime['deadline'].dt.to_period('M')
dftime

# %% [markdown]
# > For more detail about `np.timedelta64()` you can read on: https://numpy.org/doc/stable/reference/arrays.datetime.html
