# %% [markdown]
# # APPLIED DATA CLEANING ON KICKSTARTER DATASET
#
# <img src='https://c3.iggcdn.com/indiegogo-media-prod-cld/image/upload/c_fill,w_695,g_auto,q_auto,dpr_2.6,f_auto,h_460/raayulrjgqrecunugw8y' width=600>

# %%
# Import pandas
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# Load dataset
# df = pd.read_csv('https://www.dropbox.com/s/k0fyjksq5c6cbvx/kickstarter_data.csv?dl=1', index_col=[0])
df = pd.read_csv('data\\kickstarter_data.csv')

# First 5 rows of the dataframe
df.sample(5)
# Out:
#         Unnamed: 0          ID                                         name  \
# 194784      194784  1991781833          Under The Radar's Creative ReLaunch
# 195025      195025  1993032191              Meat is Murdered : a Rock Opera
# 228431      228431   231242167                          Virtual Art Gallery
# 156580      156580  1796494261  Cornwalls first gourmet takeaway restaurant
# 209740      209740  2068971849                           2Empires the Novel
#
#            category main_category currency    deadline     goal  \
# 194784        Faith         Music      USD  2016-11-16  13000.0
# 195025      Theater       Theater      USD  2012-03-02   8000.0
# 228431  Digital Art           Art      GBP  2016-09-24    400.0
# 156580         Food          Food      GBP  2014-02-06   3500.0
# 209740      Fiction    Publishing      USD  2015-06-05  30651.0
#
#                    launched   pledged       state  backers country  \
# 194784  2016-10-13 16:20:36  16479.77  successful      223      US
# 195025  2012-01-21 02:13:57      0.00      failed        0      US
# 228431  2016-08-25 20:05:41      3.00      failed        1      GB
# 156580  2014-01-07 18:16:55     90.00      failed        6      GB
# 209740  2015-05-05 05:04:05    390.00      failed        7      US
#
#         usd pledged  usd_pledged_real  usd_goal_real
# 194784      3397.00          16479.77       13000.00
# 195025         0.00              0.00        8000.00
# 228431         0.00              3.89         518.50
# 156580       147.26            146.94        5714.38
# 209740       390.00            390.00       30651.00

# %%
df = df.iloc[:, 1:]

# %%
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# 1  2017-09-02 04:43:57   2421.0    failed       15      US        100.0
# 2  2013-01-12 00:20:50    220.0    failed        3      US        220.0
# 3  2012-03-17 03:24:11      1.0    failed        1      US          1.0
# 4  2015-07-04 08:35:03   1283.0  canceled       14      US       1283.0
#
#    usd_pledged_real  usd_goal_real
# 0               0.0        1533.95
# 1            2421.0       30000.00
# 2             220.0       45000.00
# 3               1.0        5000.00
# 4            1283.0       19500.00

# %% [markdown]
# **ANNOTATION**
#
# - Question: *graded* exercises to complete for score
#
# - Task: *not graded* exercises, highly recommended to follow through
#
# - Dataframe Columns:
#     - `goal`: Goal set at the launched time.
#
#     - `pledge`: Total amount of funding the project successfully called.
#
#     - `backers`: Number of investors that fund the project.
#
#     - `usd pledged`: conversion in US dollars of the pledged column (conversion done by kickstarter).
#
#     - `usd_pledge_real`: conversion in US dollars of the pledged column (conversion from Fixer.io API).
#
#     - `usd_goal_real`: conversion in US dollars of the goal column (conversion from Fixer.io API).
#
# The dataset is acquired from Kaggle.com. You can visit it here: https://www.kaggle.com/kemical/kickstarter-projects

# %% [markdown]
# 🙋🏻‍♂️ **DISCUSSION :** Discuss with your teammate to:
#
# - Understand the meaning of each column
# - Is there any column that you feel unnecessary?

# %% [markdown]
# # A. OVERVIEW AND CLEAN

# %% [markdown]
# ## **A.1** - Remove unwanted observations
# ---

# %% [markdown]
# ### Task

# %% [markdown]
# We have many columns for the pledge and goal with different conversions. For this analysis, we choose to keep only `usd_pledged_real` and `usd_goal_real`.
#
# Write one line of code to drop the columns `goal`, `pledge`, `usd pledged`.

# %%
df.columns
# Out:
# Index(['ID', 'name', 'category', 'main_category', 'currency', 'deadline',
#        'goal', 'launched', 'pledged', 'state', 'backers', 'country',
#        'usd pledged', 'usd_pledged_real', 'usd_goal_real'],
#       dtype='object')

# %%
# YOUR CODE/ANSWER HERE
df.drop(columns = ['goal', 'pledged', 'usd pledged'], inplace = True)

# %%
# Check your dataframe again to see if the columns are successfully dropped
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline             launched  \
# 0          Poetry    Publishing      GBP  2015-10-09  2015-08-11 12:12:28
# 1  Narrative Film  Film & Video      USD  2017-11-01  2017-09-02 04:43:57
# 2  Narrative Film  Film & Video      USD  2013-02-26  2013-01-12 00:20:50
# 3           Music         Music      USD  2012-04-16  2012-03-17 03:24:11
# 4    Film & Video  Film & Video      USD  2015-08-29  2015-07-04 08:35:03
#
#       state  backers country  usd_pledged_real  usd_goal_real
# 0    failed        0      GB               0.0        1533.95
# 1    failed       15      US            2421.0       30000.00
# 2    failed        3      US             220.0       45000.00
# 3    failed        1      US               1.0        5000.00
# 4  canceled       14      US            1283.0       19500.00

# %% [markdown]
# For future convenience, let's rename the columns as follows:
#
# - `usd_pledged_real` --> `pledged`
# - `usd_goal_real` --> `goal`
#
# Write your code to do that below.

# %%
# YOUR CODE HERE
df.rename(columns = {'usd_pledged_real' : 'pledged', 'usd_goal_real': 'goal'}, inplace = True)

# %%
# Check your dataframe again to see if your columns are successfully renamed
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline             launched  \
# 0          Poetry    Publishing      GBP  2015-10-09  2015-08-11 12:12:28
# 1  Narrative Film  Film & Video      USD  2017-11-01  2017-09-02 04:43:57
# 2  Narrative Film  Film & Video      USD  2013-02-26  2013-01-12 00:20:50
# 3           Music         Music      USD  2012-04-16  2012-03-17 03:24:11
# 4    Film & Video  Film & Video      USD  2015-08-29  2015-07-04 08:35:03
#
#       state  backers country  pledged      goal
# 0    failed        0      GB      0.0   1533.95
# 1    failed       15      US   2421.0  30000.00
# 2    failed        3      US    220.0  45000.00
# 3    failed        1      US      1.0   5000.00
# 4  canceled       14      US   1283.0  19500.00

# %% [markdown]
# ### Question 1 (5 pts)

# %% [markdown]
# Write one line of code to check for duplications (of the whole row). Your code should return only one number, which is the total number of duplicated rows.

# %%
# TEST YOUR CODE HERE
df.duplicated().sum()
# Out:
# 0

# %%
# Check duplicate for ID:
df.ID.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Question 2 (5 pts)

# %% [markdown]
# How about duplicated values in the column `name`? Which of the following expression gives the number of rows with duplicated names?
#
# <ol type="A">
#   <li><code>df['name'].isduplicated().sum()</code></li>
#   <li><code>df[df['name'].duplicated()].sum()</code></li>
#   <li><code>df['name'].duplicated().sum()</code></li>
#   <li><code>df.duplicated().sum()</code></li>
# </ol>

# %%
# YOUR CODE/ANSWER HERE => C
df.name.duplicated().sum()
# Out:
# 2896

# %% [markdown]
# ### Question 3 (5 pts)

# %% [markdown]
# Which of the following expression selects all rows with duplicated names?
#
# <ol type="A">
#   <li><code>df(df['name'].duplicated())</code></li>
#   <li><code>df[df['name'].duplicated()]</code></li>
#   <li><code>df['name'].duplicated()</code></li>
#   <li><code>df[df.duplicated()]</code></li>
# </ol>

# %%
# TEST YOUR CODE HERE => B
df[df.name.duplicated()]
# Out:
#                 ID                      name          category main_category  \
# 6379    1032645935      Cancelled (Canceled)            Design        Design
# 7743    1039093987  New EP/Music Development             Music         Music
# 8356    1042208764              The Basement            Horror  Film & Video
# 8448    1042642941                  The Gift      Film & Video  Film & Video
# 8761    1044230780                Redemption    Narrative Film  Film & Video
# ...            ...                       ...               ...           ...
# 378140   997542782              Innocent Sin        Indie Rock         Music
# 378224   997919903                Grassroots        Publishing    Publishing
# 378426   998836498              The InAction  Camera Equipment    Technology
# 378475   999055513           The Last Hurrah              Rock         Music
# 378548   999410766                     Guilt            Shorts  Film & Video
#
#        currency    deadline             launched       state  backers country  \
# 6379        USD  2015-06-05  2015-05-06 12:29:08    canceled       17      US
# 7743        USD  2016-01-07  2015-11-24 15:29:35   undefined        0    N,0"
# 8356        USD  2015-05-07  2015-04-07 18:24:19  successful      106      US
# 8448        USD  2013-05-08  2013-04-17 01:55:27  successful       37      US
# 8761        USD  2012-08-25  2012-06-26 19:13:21  successful       67      US
# ...         ...         ...                  ...         ...      ...     ...
# 378140      USD  2015-01-25  2014-12-26 18:04:28  successful       15      US
# 378224      EUR  2017-09-14  2017-08-15 18:36:18      failed        3      IE
# 378426      USD  2016-07-29  2016-06-28 04:00:08    canceled        5      US
# 378475      USD  2012-06-03  2012-05-04 15:20:41  successful       69      US
# 378548      USD  2014-05-16  2014-04-16 17:45:46      failed        7      US
#
#          pledged       goal
# 6379     3105.00  100000.00
# 7743      257.00    3800.00
# 8356    12311.00   12000.00
# 8448     3370.00    3000.00
# 8761    11440.00   11000.00
# ...          ...        ...
# 378140    600.00     300.00
# 378224     25.12   11963.01
# 378426    670.00   80000.00
# 378475   7665.00    5500.00
# 378548    791.00   65000.00
#
# [2896 rows x 12 columns]

# %% [markdown]
# ### Task

# %% [markdown]
# From duplicated **name**, Let's search for all the rows that have name '**The Gift**'.

# %%
# YOUR CODE HERE
df[df.name == 'The Gift']
# Out:
#                 ID      name      category main_category currency    deadline  \
# 5003    1025568649  The Gift        Shorts  Film & Video      USD  2014-05-10
# 8448    1042642941  The Gift  Film & Video  Film & Video      USD  2013-05-08
# 77475   1394078347  The Gift        Shorts  Film & Video      USD  2011-04-09
# 135140   168615922  The Gift        Shorts  Film & Video      USD  2011-12-31
#
#                    launched       state  backers country  pledged     goal
# 5003    2014-04-29 03:14:49  successful       27      US   4560.0   4500.0
# 8448    2013-04-17 01:55:27  successful       37      US   3370.0   3000.0
# 77475   2011-03-09 00:15:36      failed        0      US      0.0   1500.0
# 135140  2011-11-01 02:28:03      failed        0      US      0.0  10000.0

# %% [markdown]
# ## **A.2** - Structural Error, Correct Datatype
# ---

# %% [markdown]
# ### Task

# %% [markdown]
# Write one line of code to print the overall information of the dataset. Are there any columns that you feel like they have the wrong datatype?

# %%
# YOUR CODE HERE
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378661 entries, 0 to 378660
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ID             378661 non-null  int64
#  1   name           378657 non-null  object
#  2   category       378661 non-null  object
#  3   main_category  378661 non-null  object
#  4   currency       378661 non-null  object
#  5   deadline       378661 non-null  object
#  6   launched       378661 non-null  object
#  7   state          378661 non-null  object
#  8   backers        378661 non-null  int64
#  9   country        378661 non-null  object
#  10  pledged        378661 non-null  float64
#  11  goal           378661 non-null  float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 34.7+ MB

# %% [markdown]
# The `launched` and `deadline` should be in `datetime` datatype, so you need to convert them to datetime datatype:
#
# *Hint: pd.to_datetime()*

# %%
# Your code here:
df.deadline = pd.to_datetime(df.deadline)
df.launched = pd.to_datetime(df.launched)

# %% [markdown]
# Check info one more time to make sure everything goes as plan.

# %%
# YOUR CODE HERE
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378661 entries, 0 to 378660
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ID             378661 non-null  int64
#  1   name           378657 non-null  object
#  2   category       378661 non-null  object
#  3   main_category  378661 non-null  object
#  4   currency       378661 non-null  object
#  5   deadline       378661 non-null  datetime64[ns]
#  6   launched       378661 non-null  datetime64[ns]
#  7   state          378661 non-null  object
#  8   backers        378661 non-null  int64
#  9   country        378661 non-null  object
#  10  pledged        378661 non-null  float64
#  11  goal           378661 non-null  float64
# dtypes: datetime64[ns](2), float64(2), int64(2), object(6)
# memory usage: 34.7+ MB

# %%
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency   deadline            launched  \
# 0          Poetry    Publishing      GBP 2015-10-09 2015-08-11 12:12:28
# 1  Narrative Film  Film & Video      USD 2017-11-01 2017-09-02 04:43:57
# 2  Narrative Film  Film & Video      USD 2013-02-26 2013-01-12 00:20:50
# 3           Music         Music      USD 2012-04-16 2012-03-17 03:24:11
# 4    Film & Video  Film & Video      USD 2015-08-29 2015-07-04 08:35:03
#
#       state  backers country  pledged      goal
# 0    failed        0      GB      0.0   1533.95
# 1    failed       15      US   2421.0  30000.00
# 2    failed        3      US    220.0  45000.00
# 3    failed        1      US      1.0   5000.00
# 4  canceled       14      US   1283.0  19500.00

# %% [markdown]
# ## **A.3** - Handling Missing Values
# ---

# %% [markdown]
# ### Question 4 (5 pts)

# %% [markdown]
# Which of the following expression(s) give the number of null values in *each* column?
#
# <ol type="A">
#   <li><code>df.isna().sum()</code></li>
#   <li><code>df.null().sum()</code></li>
#   <li><code>df.isnull().sum()</code></li>
#   <li><code>sum(df.isnull())</code></li>
#   <li><code>df.isna.sum()</code></li>
#   <li><code>sum(df.isna())</code></li>
# </ol>

# %%
# TEST YOUR CODE HERE
df.isna().sum()
# Out:
# ID               0
# name             4
# category         0
# main_category    0
# currency         0
# deadline         0
# launched         0
# state            0
# backers          0
# country          0
# pledged          0
# goal             0
# dtype: int64

# %%
df[df.name.isna()]
# Out:
#                 ID name        category main_category currency   deadline  \
# 166851  1848699072  NaN  Narrative Film  Film & Video      USD 2012-02-29
# 307234   634871725  NaN     Video Games         Games      GBP 2013-01-06
# 309991   648853978  NaN  Product Design        Design      USD 2016-07-18
# 338931   796533179  NaN        Painting           Art      USD 2011-12-05
#
#                   launched      state  backers country  pledged       goal
# 166851 2012-01-01 12:35:31     failed        1      US   100.00  200000.00
# 307234 2012-12-19 23:57:48     failed       12      GB   316.05    3224.97
# 309991 2016-06-18 05:01:47  suspended        0      US     0.00    2500.00
# 338931 2011-11-06 23:55:55     failed        5      US   220.00   35000.00

# %% [markdown]
# ### Task

# %% [markdown]
# Write one line of code to fill all the `NaN` values in name with `Unknown`.

# %%
# YOUR CODE HERE
df.fillna('Unknown', inplace = True)

# %% [markdown]
# Check the number of `NaN` value one more time to make sure we cleaned them all.

# %%
# YOUR CODE HERE
df.isna().sum()
# Out:
# ID               0
# name             0
# category         0
# main_category    0
# currency         0
# deadline         0
# launched         0
# state            0
# backers          0
# country          0
# pledged          0
# goal             0
# dtype: int64

# %% [markdown]
# ## **A.4** - Handling errors, corrupted data
# ---

# %% [markdown]
# Scanning through each column to find abnormalities and fix them. Simple as that.

# %%
# Display the dataframe one more time.
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency   deadline            launched  \
# 0          Poetry    Publishing      GBP 2015-10-09 2015-08-11 12:12:28
# 1  Narrative Film  Film & Video      USD 2017-11-01 2017-09-02 04:43:57
# 2  Narrative Film  Film & Video      USD 2013-02-26 2013-01-12 00:20:50
# 3           Music         Music      USD 2012-04-16 2012-03-17 03:24:11
# 4    Film & Video  Film & Video      USD 2015-08-29 2015-07-04 08:35:03
#
#       state  backers country  pledged      goal
# 0    failed        0      GB      0.0   1533.95
# 1    failed       15      US   2421.0  30000.00
# 2    failed        3      US    220.0  45000.00
# 3    failed        1      US      1.0   5000.00
# 4  canceled       14      US   1283.0  19500.00

# %% [markdown]
# ### Question 5 (5 pts)

# %% [markdown]
# Let's start with `category`. Write an expression to display the frequency of the value in the column `category`. (The unique values and how many times they appear)

# %%
pd.set_option('display.max_rows', None)     # show full rows
pd.set_option('display.max_columns', None)  # show full columns

# %%
# TEST YOUR CODE HERE
df.category.value_counts()
# Out:
# Product Design        22314
# Documentary           16139
# Music                 15727
# Tabletop Games        14180
# Shorts                12357
# Video Games           11830
# Food                  11493
# Film & Video          10108
# Fiction                9169
# Fashion                8554
# Nonfiction             8318
# Art                    8253
# Apparel                7166
# Theater                7057
# Technology             6930
# Rock                   6758
# Children's Books       6756
# Apps                   6345
# Publishing             6018
# Webseries              5762
# Photography            5752
# Indie Rock             5657
# Narrative Film         5188
# Web                    5153
# Comics                 4996
# Crafts                 4664
# Country & Folk         4451
# Design                 4199
# Hip-Hop                3912
# Hardware               3663
# Pop                    3350
# Painting               3294
# Games                  3226
# Illustration           3175
# Accessories            3165
# Public Art             3077
# Software               3048
# Gadgets                2965
# Restaurants            2819
# Mixed Media            2757
# Comic Books            2743
# Art Books              2676
# Classical Music        2613
# Animation              2541
# Playing Cards          2497
# Drinks                 2422
# Dance                  2322
# Comedy                 2320
# Drama                  2179
# Electronic Music       2170
# Performance Art        2154
# World Music            2102
# Graphic Design         2002
# Graphic Novels         1864
# Jazz                   1850
# Sculpture              1810
# Small Batch            1808
# Mobile Games           1789
# Food Trucks            1752
# Journalism             1747
# Photobooks             1580
# Plays                  1378
# Poetry                 1369
# Digital Art            1346
# Horror                 1287
# Periodicals            1265
# Jewelry                1239
# Wearables              1233
# DIY                    1173
# Woodworking            1167
# Farms                  1154
# People                 1103
# Faith                  1092
# Live Games             1050
# Conceptual Art         1030
# Television             1015
# Performances           1013
# Footwear                931
# Experimental            924
# Radio & Podcasts        923
# Academic                916
# Musical                 913
# DIY Electronics         902
# Ready-to-wear           864
# Spaces                  841
# Festivals               839
# Young Adult             821
# Events                  818
# Anthologies             784
# Fine Art                776
# Architecture            760
# Thrillers               746
# Science Fiction         744
# Action                  740
# Places                  739
# Print                   727
# Metal                   717
# Music Videos            709
# 3D Printing             683
# Sound                   669
# Webcomics               648
# Vegan                   588
# Nature                  574
# Robots                  572
# Cookbooks               540
# Childrenswear           483
# Installations           482
# R&B                     458
# Candles                 429
# Video                   428
# Gaming Hardware         428
# Flight                  426
# Farmer's Markets        424
# Camera Equipment        416
# Audio                   410
# Interactive Design      398
# Zines                   391
# Fantasy                 345
# Family                  336
# Immersive               330
# Calendars               329
# Space Exploration       323
# Punk                    317
# Ceramics                305
# Community Gardens       298
# Civic Design            289
# Kids                    285
# Literary Journals       278
# Textiles                276
# Couture                 275
# Blues                   268
# Animals                 255
# Fabrication Tools       250
# Makerspaces             238
# Printing                238
# Movie Theaters          232
# Puzzles                 231
# Bacon                   221
# Stationery              219
# Photo                   196
# Video Art               194
# Romance                 190
# Knitting                181
# Workshops               164
# Crochet                 162
# Translations            153
# Pet Fashion             139
# Glass                   138
# Latin                   137
# Embroidery              113
# Typography              108
# Pottery                 100
# Weaving                  93
# Quilts                   81
# Residencies              69
# Letterpress              49
# Chiptune                 35
# Literary Spaces          27
# Taxidermy                13
# Name: category, dtype: int64

# %% [markdown]
# ### Question 6 (5 pts)

# %% [markdown]
# Everything seems fine. We now move on to `main_category`. Write an expression to display the frequency of the value in the column `main_category`.

# %%
# TEST YOUR CODE HERE
df.main_category.value_counts()
# Out:
# Film & Video    63585
# Music           51918
# Publishing      39874
# Games           35231
# Technology      32569
# Design          30070
# Art             28153
# Food            24602
# Fashion         22816
# Theater         10913
# Comics          10819
# Photography     10779
# Crafts           8809
# Journalism       4755
# Dance            3768
# Name: main_category, dtype: int64

# %% [markdown]
# ### Task

# %% [markdown]
# Let's do the same for `currency` and `state`. Find anything abnormal?

# %%
# YOUR CODE HERE
df.currency.value_counts()
# Out:
# USD    295365
# GBP     34132
# EUR     17405
# CAD     14962
# AUD      7950
# SEK      1788
# MXN      1752
# NZD      1475
# DKK      1129
# CHF       768
# NOK       722
# HKD       618
# SGD       555
# JPY        40
# Name: currency, dtype: int64

# %%
# YOUR CODE HERE
df.state.value_counts()
# Out:
# failed        197719
# successful    133956
# canceled       38779
# undefined       3562
# live            2799
# suspended       1846
# Name: state, dtype: int64

# %% [markdown]
# ### Question 7 (5 pts)

# %% [markdown]
# Are there any abnormalities in the column `country`?
#
# <ol type="A">
#   <li>Nope, totally fine.</li>
#   <li>There is no project in US.</li>
#   <li>There are two different values that both represent Canada.</li>
#   <li>There is a weird value called <code>N,0"</code>.</li>
# </ol>

# %% [markdown]
# D

# %%
# TEST YOUR CODE HERE
df.country.value_counts()
# Out:
# US      292627
# GB       33672
# CA       14756
# AU        7839
# DE        4171
# N,0"      3797
# FR        2939
# IT        2878
# NL        2868
# ES        2276
# SE        1757
# MX        1752
# NZ        1447
# DK        1113
# IE         811
# CH         761
# NO         708
# HK         618
# BE         617
# AT         597
# SG         555
# LU          62
# JP          40
# Name: country, dtype: int64

# %% [markdown]
# #### *Click to see my solution*

# %% [markdown]
# One way to adjust the error in the column `country` is to refer it with the column `currency`.
#
# For example, if the `currency` is `USD`, we can set the value in `country` to `US`.

# %% [markdown]
# ### Question 8 (5 pts)

# %% [markdown]
# Write an expression to select all rows with that weird value above (`N,0"`).

# %%
# TEST YOUR CODE HERE
df[df.country == 'N,0"'].sample(5)
# Out:
#                 ID                                               name  \
# 99059   1502868750                      Send QUEL BORDEL! to France!!
# 275680   472780736                                  Midnight Carnival
# 276801   478264169                                         White Road
# 270310   445494223          The Adventures of the Three Little Clouds
# 62319   1316880473  'The Girl On Christopher Street' official Vide...
#
#             category main_category currency   deadline            launched  \
# 99059          Music         Music      USD 2015-03-18 2015-02-23 20:32:00
# 275680  Film & Video  Film & Video      USD 2015-05-28 2015-04-28 16:13:18
# 276801  Film & Video  Film & Video      USD 2016-03-06 2016-02-05 13:48:53
# 270310    Publishing    Publishing      USD 2015-12-09 2015-11-09 05:04:15
# 62319          Music         Music      GBP 2015-11-03 2015-10-02 10:55:28
#
#             state  backers country  pledged     goal
# 99059   undefined        0    N,0"  5846.00  5000.00
# 275680  undefined        0    N,0"  3047.00  2500.00
# 276801  undefined        0    N,0"  5930.00  4500.00
# 270310  undefined        0    N,0"     0.00  6000.00
# 62319   undefined        0    N,0"  5086.44  4541.46

# %% [markdown]
# ### Question 9 (5 pts)

# %% [markdown]
# Write one line of code to return the ***unique currencies*** of the projects that have country as `N,0"`?

# %%
# TEST YOUR CODE HERE
df[df.country == 'N,0"']['currency'].unique()
# Out:
# array(['USD', 'AUD', 'CAD', 'GBP', 'EUR', 'SEK', 'DKK', 'NZD', 'NOK',
#        'CHF'], dtype=object)

# %% [markdown]
# ### Task

# %% [markdown]
# Our mission is apply a check function onto each row of the country-N0" part.
#
# First, define a function that takes in a whole data row.
#
# - If currency is `USD` ---> country is `US`
# - If currency is `AUD` ---> country is `AU`
# - If currency is `CAD` ---> country is `CA`
# - If currency is `GBP` ---> country is `GB`
# - If currency is `SEK` ---> country is `SE`
# - If currency is `DKK` ---> country is `DK`
# - If currency is `NZD` ---> country is `NZ`
# - If currency is `NOK` ---> country is `NO`
# - If currency is `CHF` ---> country is `CH`
# - If currency is `EUR` ---> country is `DE`
#
# In the `EUR` case, we choose to replace by the mode --- `DE` (Within projects that in `EUR`, the most are from `DE` -- Germany)

# %%
def fix_country(row):
    if row['currency'] == 'EUR':
        return 'DE'
    else:
        return row['currency'][:2]

# %%
# Apply and then write it back to the dataframe
df.loc[df.country == 'N,0"', 'country'] = df.apply(fix_country, axis = 1)

# %%
# Check the column again to make sure the N0" is gone
df['country'].value_counts()
# Out:
# US    295365
# GB     34132
# CA     14962
# AU      7950
# DE      4357
# FR      2939
# IT      2878
# NL      2868
# ES      2276
# SE      1788
# MX      1752
# NZ      1475
# DK      1129
# IE       811
# CH       768
# NO       722
# HK       618
# BE       617
# AT       597
# SG       555
# LU        62
# JP        40
# Name: country, dtype: int64

# %% [markdown]
# ### Question 10 (5 pts)

# %% [markdown]
# Let's move on to the numeric columns.
#
# Write one line of code to give the descriptive statistic review of three columns: `backers`, `pledged`, and `goal`.

# %%
# TEST YOUR CODE HERE
df[['backers', 'pledged', 'goal']].describe()
# Out:
#              backers       pledged          goal
# count  378661.000000  3.786610e+05  3.786610e+05
# mean      105.617476  9.058924e+03  4.545440e+04
# std       907.185035  9.097334e+04  1.152950e+06
# min         0.000000  0.000000e+00  1.000000e-02
# 25%         2.000000  3.100000e+01  2.000000e+03
# 50%        12.000000  6.243300e+02  5.500000e+03
# 75%        56.000000  4.050000e+03  1.550000e+04
# max    219382.000000  2.033899e+07  1.663614e+08

# %% [markdown]
# 💡 **Tips:** Your question right now is what the heck is `e+05` and `e+04`. This in Python called scientific style. `e+04` means `*10e4` or `*10000`.
#
# If you don't like it, you can use the syntax below. After you run the code, all the report later will be printed in 2 decimal float format.

# %%
pd.options.display.float_format = "{:.2f}".format
# let's run df.describe() again:
df[['backers', 'pledged', 'goal']].describe()
# Out:
#         backers     pledged         goal
# count 378661.00   378661.00    378661.00
# mean     105.62     9058.92     45454.40
# std      907.19    90973.34   1152950.06
# min        0.00        0.00         0.01
# 25%        2.00       31.00      2000.00
# 50%       12.00      624.33      5500.00
# 75%       56.00     4050.00     15500.00
# max   219382.00 20338986.27 166361390.71

# %% [markdown]
# Everything seems fine. No projects have abnormality in these numeric columns.

# %% [markdown]
# ### Question 11 (10 pts)

# %% [markdown]
# 👑 **The best project** --- Write one line of code to get the row of the project that have the max pledged.

# %%
# TEST YOUR CODE HERE
df[df.pledged == df.pledged.max()]
# Out:
#                 ID                                              name  \
# 157270  1799979574  Pebble Time - Awesome Smartwatch, No Compromises
#
#               category main_category currency   deadline            launched  \
# 157270  Product Design        Design      USD 2015-03-28 2015-02-24 15:44:42
#
#              state  backers country     pledged      goal
# 157270  successful    78471      US 20338986.27 500000.00

# %% [markdown]
# You have done a lot of coding. Now, take a bit time off, google and read about this awesome product design project called `'Pebble Time - Awesome Smartwatch, No Compromises'` that attracts the most pledge on Kickstarter history.

# %% [markdown]
# ### Question 12 (10 pts)

# %% [markdown]
# ❤️ **The top favorite** --- Write one line of code to get the row of the project that have the max backers.

# %%
# TEST YOUR CODE HERE
df[df.backers == df.backers.max()]
# Out:
#                 ID               name        category main_category currency  \
# 187652  1955357092  Exploding Kittens  Tabletop Games         Games      USD
#
#          deadline            launched       state  backers country    pledged  \
# 187652 2015-02-20 2015-01-20 19:00:19  successful   219382      US 8782571.99
#
#            goal
# 187652 10000.00

# %% [markdown]
# Is the product sounds familiar? You can buy this at any convenient store in Vietnam nowaday. 🥳

# %% [markdown]
# ### Question 13 (10 pts)

# %% [markdown]
# 🤑 **The most ambitious** --- Write one line of code to get the row of the project that set the max goal.

# %%
# TEST YOUR CODE HERE
df[df.goal == df.goal.max()]
# Out:
#                ID                                       name category  \
# 47803  1243678698  FUCK Potato Salad. Paleo Potato Brownies!     Food
#
#       main_category currency   deadline            launched   state  backers  \
# 47803          Food      GBP 2014-08-08 2014-07-09 00:24:34  failed        0
#
#       country  pledged         goal
# 47803      GB     0.00 166361390.71

# %% [markdown]
# ### Finally, the last two columns left are the two datetime `launched` and `deadline`.

# %% [markdown]
# ### Question 14 (10 pts)

# %% [markdown]
# Write one line of code to get the minimum value of the column `launched`.

# %%
# TEST YOUR CODE HERE
df.launched.min()
# Out:
# Timestamp('1970-01-01 01:00:00')

# %% [markdown]
# ### Question 15 (10 pts)

# %% [markdown]
# Write one line of code to get the maximum value of the column `launched`.

# %%
# TEST YOUR CODE HERE
df.launched.max()
# Out:
# Timestamp('2018-01-02 15:02:31')

# %% [markdown]
# - The earliest data --- 1970 doesn't make sense at all. So we filter out all the data that set launched year before the founding of Kickstarter (2009).
#
# - The latest data is in the second day of 2018. That's not enough to have a view for 2018 and might effect to analysis in year level, or month level. So we exclude the incomplete data of 2018.

# %% [markdown]
# 👉 Do you still remember how to extract datetime components from a date:
#
# ```python
# # Extract year, month, day
# date_series.dt.year
# date_series.dt.month
# date_series.dt.day
#
# # Extract hour, minute, second
# date_series.dt.hour
# date_series.dt.minute
# date_series.dt.second
#
# # Extract dayofweek, week, quarter
# date_series.dt.dayofweek
# date_series.dt.isocalendar().week
# date_series.dt.quarter
#
# # Extract year-month
# date_series.dt.to_period('M')
# ```

# %% [markdown]
# + Choose to work with data from the beginning of the year 2009 to the end of the year 2017 only.

# %%
# Choose to work with data from the beginning of the year 2009 to the end of the year 2017 only.
# FILL-IN THE ___ BELOW:
df2 = df[(df['launched'].dt.year > 2009) & (df['launched'].dt.year < 2018)]

# %%
df2.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency   deadline            launched  \
# 0          Poetry    Publishing      GBP 2015-10-09 2015-08-11 12:12:28
# 1  Narrative Film  Film & Video      USD 2017-11-01 2017-09-02 04:43:57
# 2  Narrative Film  Film & Video      USD 2013-02-26 2013-01-12 00:20:50
# 3           Music         Music      USD 2012-04-16 2012-03-17 03:24:11
# 4    Film & Video  Film & Video      USD 2015-08-29 2015-07-04 08:35:03
#
#       state  backers country  pledged     goal
# 0    failed        0      GB     0.00  1533.95
# 1    failed       15      US  2421.00 30000.00
# 2    failed        3      US   220.00 45000.00
# 3    failed        1      US     1.00  5000.00
# 4  canceled       14      US  1283.00 19500.00

# %%
# Check the column one more time
df2['launched'].min()
# Out:
# Timestamp('2010-01-01 01:41:03')

# %%
df2['launched'].max()
# Out:
# Timestamp('2017-12-31 23:37:20')

# %% [markdown]
# ### Final Task
#
# The last task that we should do in cleaning this dataset is to create new columns extract `day`, `month`, `year` from the two columns `launched` and `deadline`. This will help us in the future when we analyse on year, on month, or on day. For example: number of project by year.
#
# In data analysis, this is a simple feature engineering.

# %%
df['launched_day'] =    df['launched'].dt.day
df['launched_month'] =  df['launched'].dt.month
df['launched_year'] =   df.launched.dt.year

# %%
# Do the same thing with deadline column
# YOUR CODE HERE
df['deadline_day'] =    df['deadline'].dt.day
df['deadline_month'] =  df['deadline'].dt.month
df['deadline_year'] =   df.deadline.dt.year

# %%
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency   deadline            launched  \
# 0          Poetry    Publishing      GBP 2015-10-09 2015-08-11 12:12:28
# 1  Narrative Film  Film & Video      USD 2017-11-01 2017-09-02 04:43:57
# 2  Narrative Film  Film & Video      USD 2013-02-26 2013-01-12 00:20:50
# 3           Music         Music      USD 2012-04-16 2012-03-17 03:24:11
# 4    Film & Video  Film & Video      USD 2015-08-29 2015-07-04 08:35:03
#
#       state  backers country  pledged     goal  launched_day  launched_month  \
# 0    failed        0      GB     0.00  1533.95            11               8
# 1    failed       15      US  2421.00 30000.00             2               9
# 2    failed        3      US   220.00 45000.00            12               1
# 3    failed        1      US     1.00  5000.00            17               3
# 4  canceled       14      US  1283.00 19500.00             4               7
#
#    launched_year  deadline_day  deadline_month  deadline_year
# 0           2015             9              10           2015
# 1           2017             1              11           2017
# 2           2013            26               2           2013
# 3           2012            16               4           2012
# 4           2015            29               8           2015

# %% [markdown]
# YAYYY!!! WE HAVE DONE EVERTHING. 🤩 Finally you got a clean dataset that is ready for analysis.
#
# Let's view out beautiful dataset again.

# %%
# View our data again
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency   deadline            launched  \
# 0          Poetry    Publishing      GBP 2015-10-09 2015-08-11 12:12:28
# 1  Narrative Film  Film & Video      USD 2017-11-01 2017-09-02 04:43:57
# 2  Narrative Film  Film & Video      USD 2013-02-26 2013-01-12 00:20:50
# 3           Music         Music      USD 2012-04-16 2012-03-17 03:24:11
# 4    Film & Video  Film & Video      USD 2015-08-29 2015-07-04 08:35:03
#
#       state  backers country  pledged     goal  launched_day  launched_month  \
# 0    failed        0      GB     0.00  1533.95            11               8
# 1    failed       15      US  2421.00 30000.00             2               9
# 2    failed        3      US   220.00 45000.00            12               1
# 3    failed        1      US     1.00  5000.00            17               3
# 4  canceled       14      US  1283.00 19500.00             4               7
#
#    launched_year  deadline_day  deadline_month  deadline_year
# 0           2015             9              10           2015
# 1           2017             1              11           2017
# 2           2013            26               2           2013
# 3           2012            16               4           2012
# 4           2015            29               8           2015

# %% [markdown]
# As you can see, cleaning data is a meticulous process that takes a lot of time. In real life, it can take up to days and requires a lot of domain knowledge. Treat this notebook as a guideline or a case study to start with. Be creative when adapt to your personal project! Good luck 🥸 🧚🏻‍♂️

# %% [markdown]
# # B. FUN TASK:

# %% [markdown]
# Using IQR to filter the projects that set the goal way too ambitious or too humble.

# %%
# Create a new column called 'exceed' which is the difference of 'pledged' and 'goal'
# YOUR CODE HERE
df['exceed'] = df.pledged - df.goal
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency   deadline            launched  \
# 0          Poetry    Publishing      GBP 2015-10-09 2015-08-11 12:12:28
# 1  Narrative Film  Film & Video      USD 2017-11-01 2017-09-02 04:43:57
# 2  Narrative Film  Film & Video      USD 2013-02-26 2013-01-12 00:20:50
# 3           Music         Music      USD 2012-04-16 2012-03-17 03:24:11
# 4    Film & Video  Film & Video      USD 2015-08-29 2015-07-04 08:35:03
#
#       state  backers country  pledged     goal  launched_day  launched_month  \
# 0    failed        0      GB     0.00  1533.95            11               8
# 1    failed       15      US  2421.00 30000.00             2               9
# 2    failed        3      US   220.00 45000.00            12               1
# 3    failed        1      US     1.00  5000.00            17               3
# 4  canceled       14      US  1283.00 19500.00             4               7
#
#    launched_year  deadline_day  deadline_month  deadline_year    exceed
# 0           2015             9              10           2015  -1533.95
# 1           2017             1              11           2017 -27579.00
# 2           2013            26               2           2013 -44780.00
# 3           2012            16               4           2012  -4999.00
# 4           2015            29               8           2015 -18217.00

# %%
# Now apply IQR on the column 'exceed', calculate the upper whisker and lower whisker
# YOUR CODE HERE
q1 = df.exceed.quantile(0.25)
q3 = df.exceed.quantile(0.75)
iqr = q3 - q1
upper = q3 + iqr*1.5
lower = q1 - iqr*1.5

lower, upper
# Out:
# (-25297.5, 15498.5)

# %% [markdown]
# Everything above the upper whisker means that the project attracts A LOT of money compared to its original goal.

# %%
# Filter out the projects that above the upper whisker.
# YOUR CODE HERE
df[df.exceed >= upper].head()
# Out:
#             ID                                               name  \
# 14  1000057089  Tombstone: Old West tabletop game and miniatur...
# 27  1000104688                                Permaculture Skills
# 31  1000117861                  Ledr workbook: one tough journal!
# 46  1000183112                            Hot Chicken Takes Over.
# 63  1000235643                                       HIIT Bottle™
#
#           category main_category currency   deadline            launched  \
# 14  Tabletop Games         Games      GBP 2017-05-03 2017-04-05 19:44:18
# 27       Webseries  Film & Video      CAD 2014-12-14 2014-11-14 18:02:00
# 31  Product Design        Design      USD 2016-10-08 2016-09-07 13:14:26
# 46     Restaurants          Food      USD 2014-10-16 2014-09-16 02:31:08
# 63          Drinks          Food      USD 2015-04-27 2015-03-13 18:33:08
#
#          state  backers country   pledged     goal  launched_day  \
# 14  successful      761      GB 121857.33  6469.73             5
# 27  successful      571      CA  42174.03 15313.04            14
# 31  successful      549      US  47266.00  1000.00             7
# 46  successful      855      US  63401.00 40000.00            16
# 63  successful     2784      US 124998.00 15000.00            13
#
#     launched_month  launched_year  deadline_day  deadline_month  \
# 14               4           2017             3               5
# 27              11           2014            14              12
# 31               9           2016             8              10
# 46               9           2014            16              10
# 63               3           2015            27               4
#
#     deadline_year    exceed
# 14           2017 115387.60
# 27           2014  26860.99
# 31           2016  46266.00
# 46           2014  23401.00
# 63           2015 109998.00

# %%
df[df.exceed >= upper].shape
# Out:
# (11766, 19)

# %% [markdown]
# Everything below the lower whisker means that the project set the goal way TOO HIGH compared to its real potential.

# %%
# Filter out the projects that below the lower whisker.
# YOUR CODE HERE
df[df.exceed < lower].sample(5)
# Out:
#                 ID                                               name  \
# 52207   1265709349  Absolutism: the Art of Composition and Combina...
# 33073   1168077047                                   This Vivid Thing
# 271406   450775778  Transition Point! Revolution, Evolution or End...
# 219284  2116958480    SC RACER: The small controller for racing games
# 272503   456479211                   NOT! Your Grandma's Water Cooler
#
#               category main_category currency   deadline            launched  \
# 52207              Art           Art      USD 2014-01-25 2013-12-26 21:48:07
# 33073   Narrative Film  Film & Video      GBP 2014-06-21 2014-05-22 22:13:42
# 271406      Nonfiction    Publishing      GBP 2014-08-09 2014-07-10 14:52:02
# 219284        Hardware    Technology      EUR 2015-10-23 2015-09-23 12:30:09
# 272503        Hardware    Technology      CAD 2015-09-25 2015-08-11 14:37:12
#
#            state  backers country  pledged      goal  launched_day  \
# 52207   canceled        4      US   301.00  32000.00            26
# 33073     failed        7      GB   407.08 102195.50            22
# 271406    failed       23      GB  4509.65  30876.56            10
# 219284    failed        7      ES   755.93  55420.08            23
# 272503    failed       15      CA  3385.41  37557.27            11
#
#         launched_month  launched_year  deadline_day  deadline_month  \
# 52207               12           2013            25               1
# 33073                5           2014            21               6
# 271406               7           2014             9               8
# 219284               9           2015            23              10
# 272503               8           2015            25               9
#
#         deadline_year     exceed
# 52207            2014  -31699.00
# 33073            2014 -101788.42
# 271406           2014  -26366.91
# 219284           2015  -54664.15
# 272503           2015  -34171.86

# %%
df[df.exceed < lower].shape
# Out:
# (48326, 19)

# %% [markdown]
# From here, you can further explore the "too successful" projects and the "too failed" projects. For example, what kind of category tend to be too-successful, what opposite? Which country they are from? etc.
#
# Feel free to code and post your insights to Community. HAVE FUNNN 🧙🏻‍♂️
